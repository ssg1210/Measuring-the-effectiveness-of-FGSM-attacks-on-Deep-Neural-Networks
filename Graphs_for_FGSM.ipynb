# %%
tfgsm = [0.12248648,  2.09247729, 22.29253853, 74.93110136, 98.66285598 ,99.96937838,
 99.97958559  ]
fgsm = [  0.59201796,  5.43023375, 37.57272634, 84.46463203, 97.91772992, 99.57129734,
 99.85709911]

# %%
import matplotlib.pyplot as plt
new_epsilon = [0.00392156862745098, 0.0196078431372549, 0.0392156862745098 ,0.0784313725490196,0.11764705882352941,0.1568627450980392,0.19607843137254902]
plt.plot(new_epsilon, fgsm, label = "Untargeted FGSM")
plt.plot(new_epsilon, tfgsm, label = "Targeted FGSM")
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Success Rate of Attacks over Epsilon 900 deep network')
plt.legend()
plt.show()

# %%
fgsm600 = [0.48067089,  5.38965024, 37.57414604, 86.1423604,  98.29208427, 99.91818368,
 99.97954592]
tfgsm600 = [6.13622418e-02, 1.40110452e+00, 2.09961137e+01, 7.59766823e+01,
 9.87727552e+01, 9.99079566e+01, 9.99795459e+01]

# %%
plt.plot(new_epsilon, fgsm600, label = "Untargeted FGSM")
plt.plot(new_epsilon, tfgsm600, label = "Targeted FGSM")
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Success Rate of Attacks over Epsilon for a 600 layer deep network ')
plt.legend()
plt.show()

# %%
fgsm300 = [0.40828825,  5.49147698, 38.80779831, 90.81351434, 98.59140553, 99.58150454,
 99.80606308]
tfgsm300 = [5.10360314e-02, 1.36776564e+00, 1.99346739e+01, 8.04225783e+01,
 9.92752884e+01, 9.99795856e+01, 9.99795856e+01]

# %%
plt.plot(new_epsilon, fgsm300, label = "Untargeted FGSM")
plt.plot(new_epsilon, tfgsm300, label = "Targeted FGSM")
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Success Rate of Attacks over Epsilon 300 layer deep network ')
plt.legend()
plt.show()
